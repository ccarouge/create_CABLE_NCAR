# %%
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np

# %%
ds=xr.open_dataset("../CABLE_AUX-dev/offline/CABLE_UNSW_GSWP3_gridinfo_0.5x0.5.nc")

# %% [markdown]
# `iveg` ranges from 1 to 17.

# %% [markdown]
# LDT data comes with fractions for each PFT in each gridcell. Here we want only the dominant PFT. So we take the `argmax` along the `sfctypes` and add 1 to start from 1 as the PFTs.

# %%
ldt=xr.open_dataset("/g/data/w35/ccc561/temp/lis_input.d01.nc")

# %%
def get_landcover(ldt):
    lat = ldt["lat"][:,0]
    lon = ldt["lon"][0,:]

    sfc1=ldt["LANDCOVER"]
    sfc1=sfc1.assign_coords({"north_south":lat})
    sfc1=sfc1.assign_coords({"east_west":lon})
    sfc1=sfc1.rename({"north_south":"latitude","east_west":"longitude"})
    return sfc1

# %%
def get_dom_type(sfc):

    sfc1=sfc.argmax(dim="sfctypes")+1
    return sfc1

# %%
sfc = get_landcover(ldt)
sfc = get_dom_type(sfc)

# %% [markdown]
# ## PFT 1

# %%
fig,(ax1,ax2) = plt.subplots(2,1,figsize=(10,10))
opts={'cmap':"tab20",'vmin':1,'vmax':17}
ds["iveg"].sel(longitude=slice(0,180)).where(ds["iveg"]==1).plot(ax=ax1,**opts)
sfc.where((sfc==1)|(sfc==5)).plot(ax=ax2,**opts)
ax1.set_title("CABLE PFT 1")
ax2.set_title("LIS PFT 1+5")
# Out:
# Text(0.5, 1.0, 'LIS PFT 1+5')

# %% [markdown]
# ## PFT 2

# %%
fig,(ax1,ax2) = plt.subplots(2,1,figsize=(10,10))
opts={'cmap':"tab20",'vmin':1,'vmax':17}
ds["iveg"].sel(longitude=slice(0,180)).where(ds["iveg"]==2).plot(ax=ax1,**opts)
sfc.where((sfc==2)).plot(ax=ax2,**opts)
ax1.set_title("CABLE PFT 2")
ax2.set_title("LIS PFT 2")
# Out:
# Text(0.5, 1.0, 'LIS PFT 2')

# %% [markdown]
# ## PFT 3

# %%
fig,(ax1,ax2) = plt.subplots(2,1,figsize=(10,10))
opts={'cmap':"tab20",'vmin':1,'vmax':17}
ds["iveg"].sel(longitude=slice(0,180)).where(ds["iveg"]==3).plot(ax=ax1,**opts)
sfc.where((sfc==3)).plot(ax=ax2,**opts)
ax1.set_title("CABLE PFT 3")
ax2.set_title("LIS PFT 3")
# Out:
# Text(0.5, 1.0, 'LIS PFT 3')

# %% [markdown]
# ## PFT 4

# %%
fig,(ax1,ax2) = plt.subplots(2,1,figsize=(10,10))
opts={'cmap':"tab20",'vmin':1,'vmax':17}
ds["iveg"].sel(longitude=slice(0,180)).where(ds["iveg"]==4).plot(ax=ax1,**opts)
sfc.where((sfc==4)).plot(ax=ax2,**opts)
ax1.set_title("CABLE PFT 4")
ax2.set_title("LIS PFT 4")
# Out:
# Text(0.5, 1.0, 'LIS PFT 4')

# %% [markdown]
# ## PFT 5

# %%
fig,(ax1,ax2) = plt.subplots(2,1,figsize=(10,10))
opts={'cmap':"tab20",'vmin':1,'vmax':17}
ds["iveg"].sel(longitude=slice(0,180)).where(ds["iveg"]==5).plot(ax=ax1,**opts)
sfc.where((sfc==7)).plot(ax=ax2,**opts)
ax1.set_title("CABLE PFT 5")
ax2.set_title("LIS PFT 7")
# Out:
# Text(0.5, 1.0, 'LIS PFT 7')

# %% [markdown]
# ## PFT 6

# %%
fig,(ax1,ax2) = plt.subplots(2,1,figsize=(10,10))
opts={'cmap':"tab20",'vmin':1,'vmax':17}
ds["iveg"].sel(longitude=slice(0,180)).where(ds["iveg"]==6).plot(ax=ax1,**opts)
sfc.where((sfc==8)|(sfc==9)|(sfc==10)).plot(ax=ax2,**opts)
ax1.set_title("CABLE PFT 6")
ax2.set_title("LIS PFT 8+9+10")
# Out:
# Text(0.5, 1.0, 'LIS PFT 8+9+10')

# %% [markdown]
# ## PFT 8

# %%
fig,(ax1,ax2) = plt.subplots(2,1,figsize=(10,10))
opts={'cmap':"tab20",'vmin':1,'vmax':17}
ds["iveg"].sel(longitude=slice(0,180)).where(ds["iveg"]==8).plot(ax=ax1,**opts)
sfc.where((sfc==18)|(sfc==19)).plot(ax=ax2,**opts)
ax1.set_title("CABLE PFT 8")
ax2.set_title("LIS PFT 18+19")
# Out:
# Text(0.5, 1.0, 'LIS PFT 18+19')

# %% [markdown]
# ## PFT 9

# %%
fig,(ax1,ax2) = plt.subplots(2,1,figsize=(10,10))
opts={'cmap':"tab20",'vmin':1,'vmax':17}
ds["iveg"].sel(longitude=slice(0,180)).where(ds["iveg"]==9).plot(ax=ax1,**opts)
sfc.where((sfc==12)|(sfc==14)).plot(ax=ax2,**opts)
ax1.set_title("CABLE PFT 9")
ax2.set_title("LIS PFT 12+14")
# Out:
# Text(0.5, 1.0, 'LIS PFT 12+14')

# %% [markdown]
# ## PFT 11

# %%
fig,(ax1,ax2) = plt.subplots(2,1,figsize=(10,10))
opts={'cmap':"tab20",'vmin':1,'vmax':17}
ds["iveg"].sel(longitude=slice(0,180)).where(ds["iveg"]==11).plot(ax=ax1,**opts)
sfc.where((sfc==11)).plot(ax=ax2,**opts)
ax1.set_title("CABLE PFT 9")
ax2.set_title("LIS PFT 11")
# Out:
# Text(0.5, 1.0, 'LIS PFT 11')

# %% [markdown]
# ## PFT 14

# %%
fig,(ax1,ax2) = plt.subplots(2,1,figsize=(10,10))
opts={'cmap':"tab20",'vmin':1,'vmax':17}
ds["iveg"].sel(longitude=slice(0,180)).where(ds["iveg"]==14).plot(ax=ax1,**opts)
sfc.where((sfc==16)).plot(ax=ax2,**opts)
ax1.set_title("CABLE PFT 14")
ax2.set_title("LIS PFT 16")
# Out:
# Text(0.5, 1.0, 'LIS PFT 16')

# %% [markdown]
# ## PFT 15

# %%
fig,(ax1,ax2) = plt.subplots(2,1,figsize=(10,10))
opts={'cmap':"tab20",'vmin':1,'vmax':17}
ds["iveg"].sel(longitude=slice(0,180)).where(ds["iveg"]==15).plot(ax=ax1,**opts)
sfc.where((sfc==13)).plot(ax=ax2,**opts)
ax1.set_title("CABLE PFT 15")
ax2.set_title("LIS PFT 13")
# Out:
# Text(0.5, 1.0, 'LIS PFT 13')

# %% [markdown]
# ## PFT 16

# %%
fig,(ax1,ax2) = plt.subplots(2,1,figsize=(10,10))
opts={'cmap':"tab20",'vmin':1,'vmax':17}
ds["iveg"].sel(longitude=slice(0,180)).where(ds["iveg"]==16).plot(ax=ax1,**opts)
sfc.where((sfc==17)).plot(ax=ax2,**opts)
ax1.set_title("CABLE PFT 16")
ax2.set_title("LIS PFT 17")
# Out:
# Text(0.5, 1.0, 'LIS PFT 17')

# %% [markdown]
# ## PFT 17

# %%
fig,(ax1,ax2) = plt.subplots(2,1,figsize=(10,10))
opts={'cmap':"tab20",'vmin':1,'vmax':17}
ds["iveg"].sel(longitude=slice(0,180)).where(ds["iveg"]==17).plot(ax=ax1,**opts)
sfc.where((sfc==15)).plot(ax=ax2,**opts)
ax1.set_title("CABLE PFT 17")
ax2.set_title("LIS PFT 15")
# Out:
# Text(0.5, 1.0, 'LIS PFT 15')

# %% [markdown]
# ## Veg types at the same spatial location

# %%
cable = ds["iveg"].sel(longitude=slice(0,180))
for iveg in range(1,18):
    unilist,unicount=np.unique(sfc.where(cable==iveg),return_counts=True)
    unilist=unilist[~np.isnan(unilist)].astype(np.int64)  # Remove NaN values
    unicount=unicount[0:unilist.size]
    sortind=unicount.argsort()  # Sort in descending order
    unilist=unilist[sortind[::-1]]
    unicount=unicount[sortind[::-1]]
    print(f"Veg type in CABLE: {iveg}")
    print(f"(LIS type, # points) {list(zip(unilist,unicount))}")
# Out:
# Veg type in CABLE: 1
# (LIS type, # points) [(5, 3334), (1, 2044), (17, 1280), (7, 159), (12, 58), (10, 52), (2, 43), (3, 42), (8, 25), (18, 10), (4, 9), (13, 6), (14, 1), (9, 1)]
# Veg type in CABLE: 2
# (LIS type, # points) [(2, 2501), (17, 644), (8, 11), (12, 7), (9, 5), (4, 2), (10, 1), (5, 1)]
# Veg type in CABLE: 3
# (LIS type, # points) [(3, 986), (7, 5), (17, 3), (1, 1)]
# Veg type in CABLE: 4
# (LIS type, # points) [(4, 68), (17, 13), (8, 2), (5, 2)]
# Veg type in CABLE: 5
# (LIS type, # points) [(7, 6375), (17, 464), (10, 37), (16, 32), (9, 25), (12, 22), (8, 17), (6, 13), (18, 13), (2, 7), (5, 7), (3, 6), (1, 6), (4, 3), (11, 2), (13, 2), (19, 2), (15, 1)]
# Veg type in CABLE: 6
# (LIS type, # points) [(10, 3702), (9, 1993), (8, 1213), (7, 91), (2, 88), (12, 51), (17, 45), (5, 17), (4, 5), (16, 4), (14, 3)]
# Veg type in CABLE: 7
# (LIS type, # points) []
# Veg type in CABLE: 8
# ...

# %% [markdown]
# ## Remap LIS PFTs

# %%
mapveg={1:(1,5),
        2:(2,),
        3:(3,),
        4:(4,),
        5:(7,),
        6:(8,9,10),
        7:(),
        8:(18,19),
        9:(12,14),
        10:(),
        11:(11,),
        12:(),
        13:(),
        14:(16,),
        15:(13,),
        16:(17,),
        17:(15,)
       }

# %%
sfc1=get_landcover(ldt)

# %%
def remap_veg(sfc1,mapveg):
    new_map = sfc1.copy()
    new_map[:,:,:] = 0.

    for iveg,comb in mapveg.items():
        if len(comb)!=0:
            for ii in comb:
                new_map[iveg-1,...]=new_map[iveg-1,...]+sfc1[ii-1,...]
    return new_map

# %%
new_map = remap_veg(sfc1,mapveg)

# %%
ldtveg_map=get_dom_type(new_map)

# %%
def plot_newveg_cable(ldtveg_map,ds,halfworld=True):
    fig,(ax1,ax2) = plt.subplots(2,1,figsize=(10,10))
    opts={'cmap':"tab20",'vmin':1,'vmax':17,'levels':17}
    if halfworld:
        ds["iveg"].sel(longitude=slice(0,180)).plot(ax=ax1,**opts)
    else:
        ds["iveg"].plot(ax=ax1,**opts)
    ldtveg_map.plot(ax=ax2,**opts)
    ax1.set_title("CABLE PFTs")
    ax2.set_title("Remapped LIS PFTs")

# %%
plot_newveg_cable(ldtveg_map,ds)

# %%
ds11=xr.open_dataset("../CABLE_AUX-dev/offline/gridinfo_CSIRO_1x1.nc")

# %%
ldt11=xr.open_dataset("/g/data/w35/ccc561/temp/lis_input.1x1.d01.nc")

# %%
sfc11=get_landcover(ldt11)
new_map11=remap_veg(sfc11,mapveg)
ldt11_vegmap = get_dom_type(new_map11)

# %%
plot_newveg_cable(ldt11_vegmap,ds11,halfworld=False)

# %%
ldt11_dom=get_dom_type(sfc11)
plot_newveg_cable(ldt11_dom,ds11,halfworld=False)

# %%
cable = ds11["iveg"]
for iveg in range(1,18):
    unilist,unicount=np.unique(ldt11_dom.where(cable==iveg),return_counts=True)
    unilist=unilist[~np.isnan(unilist)].astype(np.int64)  # Remove NaN values
    unicount=unicount[0:unilist.size]
    sortind=unicount.argsort()  # Sort in descending order
    unilist=unilist[sortind[::-1]]
    unicount=unicount[sortind[::-1]]
    print(f"Veg type in CABLE: {iveg}")
    print(f"(LIS type, # points) {list(zip(unilist,unicount))}")
# Out:
# Veg type in CABLE: 1
# (LIS type, # points) [(1, 968), (5, 812), (17, 73), (3, 55), (12, 50), (2, 28), (10, 22), (7, 18), (14, 14), (4, 10), (18, 3), (13, 3), (8, 2), (15, 1), (9, 1)]
# Veg type in CABLE: 2
# (LIS type, # points) [(2, 1120), (17, 59), (5, 11), (10, 10), (8, 7), (7, 7), (15, 5), (1, 5), (4, 3), (12, 2), (14, 1), (9, 1)]
# Veg type in CABLE: 3
# (LIS type, # points) [(3, 165), (7, 5)]
# Veg type in CABLE: 4
# (LIS type, # points) [(5, 166), (2, 138), (4, 126), (12, 76), (17, 69), (8, 60), (14, 22), (9, 15), (10, 12), (7, 8), (16, 2), (1, 1)]
# Veg type in CABLE: 5
# (LIS type, # points) [(7, 400), (17, 7), (10, 7), (6, 5), (12, 3), (8, 2)]
# Veg type in CABLE: 6
# (LIS type, # points) [(10, 467), (12, 265), (9, 219), (8, 123), (17, 49), (14, 33), (7, 19), (5, 13), (2, 12), (1, 5), (13, 2), (4, 2)]
# Veg type in CABLE: 7
# (LIS type, # points) [(9, 533), (10, 206), (8, 164), (17, 31), (14, 27), (12, 18), (2, 16), (7, 15), (16, 1), (5, 1)]
# Veg type in CABLE: 8
# ...

# %%
map_veg11={
    1:(1,5),
    2:(2,),
    3:(3,),
    4:(4,),
    5:(),
    6:(10,),
    7:(9,8),
    8:(18,),
    9:(12,),
    10:(),
    11:(),
    12:(),
    13:(),
    14:(16,7,19),
    15:(),
    16:(17,),
    17:(15,)
}

# %%
fig,(ax1,ax2) = plt.subplots(2,1,figsize=(10,10))
opts={'cmap':"tab20",'vmin':1,'vmax':17}
ds11["iveg"].where(ds11["iveg"]==1).plot(ax=ax1,**opts)
ldt11_dom.where((ldt11_dom==1)|(ldt11_dom==5)).plot(ax=ax2,**opts)
ax1.set_title("CABLE PFT 1")
ax2.set_title("LIS PFT 1+5")
# Out:
# Text(0.5, 1.0, 'LIS PFT 1')

# %%
fig,(ax1,ax2) = plt.subplots(2,1,figsize=(10,10))
opts={'cmap':"tab20",'vmin':1,'vmax':17}
ds11["iveg"].where(ds11["iveg"]==2).plot(ax=ax1,**opts)
ldt11_dom.where((ldt11_dom==2)).plot(ax=ax2,**opts)
ax1.set_title("CABLE PFT 2")
ax2.set_title("LIS PFT 2")
# Out:
# Text(0.5, 1.0, 'LIS PFT 2')

# %%
fig,(ax1,ax2) = plt.subplots(2,1,figsize=(10,10))
opts={'cmap':"tab20",'vmin':1,'vmax':17}
ds11["iveg"].where(ds11["iveg"]==3).plot(ax=ax1,**opts)
ldt11_dom.where((ldt11_dom==3)).plot(ax=ax2,**opts)
ax1.set_title("CABLE PFT 3")
ax2.set_title("LIS PFT 3")
# Out:
# Text(0.5, 1.0, 'LIS PFT 3')

# %%
# New mapping:
sfc11=get_landcover(ldt11)
new_map11=remap_veg(sfc11,map_veg11)
ldt11_newmap = get_dom_type(new_map11)

# %%
plot_newveg_cable(ldt11_newmap,ds11,halfworld=False)

# %%
map_veg11_test={
    1:(1,),
    2:(2,5),
    3:(3,),
    4:(4,),
    5:(),
    6:(6,7),
    7:(8,9,10),
    8:(18,),
    9:(12,),
    10:(),
    11:(11,),
    12:(14,),
    13:(),
    14:(16,19),
    15:(13,),
    16:(17,),
    17:(15,)
}
sfc11=get_landcover(ldt11)
new_map11=remap_veg(sfc11,map_veg11_test)
ldt11_newmap = get_dom_type(new_map11)
plot_newveg_cable(ldt11_newmap,ds11,halfworld=False)
